# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd

# %%
res=requests.get("https://dragonball-api.com/api/characters/1")
data=res.json()
df=pd.json_normalize(data)
df
# Out:
#    id  name          ki          maxKi    race gender  \
# 0   1  Goku  60.000.000  90 Septillion  Saiyan   Male
#
#                                          description  \
# 0  El protagonista de la serie, conocido por su g...
#
#                                                image affiliation deletedAt  \
# 0  https://dragonball-api.com/characters/goku_nor...   Z Fighter      None
#
#                                      transformations  originPlanet.id  \
# 0  [{'id': 1, 'name': 'Goku SSJ', 'image': 'https...                3
#
#   originPlanet.name  originPlanet.isDestroyed  \
# 0            Vegeta                      True
#
#                             originPlanet.description  \
# 0  El planeta Vegeta, conocido como planeta Plant...
#
#                                   originPlanet.image originPlanet.deletedAt
# 0  https://dragonball-api.com/planetas/Planeta_Ve...                   None
